# %%
import pandas as pd
import numpy as np
import requests
import statsapi
import json
from datetime import date
import re

# %%
#get todays date
today = date.today()
today = today.strftime("%m/%d/%Y")
today
# Out:
# '08/19/2022'

# %%
sched = statsapi.schedule('08/20/2022')
sched
# Out:
# [{'game_id': 661628,
#   'game_datetime': '2022-08-20T17:05:00Z',
#   'game_date': '2022-08-20',
#   'game_type': 'R',
#   'status': 'In Progress',
#   'away_name': 'New York Mets',
#   'home_name': 'Philadelphia Phillies',
#   'away_id': 121,
#   'home_id': 143,
#   'doubleheader': 'S',
#   'game_num': 1,
#   'home_probable_pitcher': 'Zack Wheeler',
#   'away_probable_pitcher': 'Trevor Williams',
#   'home_pitcher_note': '',
#   'away_pitcher_note': '',
#   'away_score': 8,
#   'home_score': 1,
#   'current_inning': 9,
#   'inning_state': 'Bottom',
#   'venue_id': 2681,
#   'venue_name': 'Citizens Bank Park',
#   'national_broadcasts': [],
#   'summary': '2022-08-20 - New York Mets (8) @ Philadelphia Phillies (1) (Bottom of the 9th)'},
#  {'game_id': 661606,
#   'game_datetime': '2022-08-20T23:15:00Z',
#   'game_date': '2022-08-20',
#   'game_type': 'R',
#   'status': 'Scheduled',
#   'away_name': 'New York Mets',
#   'home_name': 'Philadelphia Phillies',
#   'away_id': 121,
#   'home_id': 143,
#   'doubleheader': 'S',
#   'game_num': 2,
#   'home_probable_pitcher': 'Bailey Falter',
#   'away_probable_pitcher': 'David Peterson',
#   'home_pitcher_note': '',
#   'away_pitcher_note': '',
#   'away_score': '0',
#   'home_score': '0',
#   'current_inning': '',
#   'inning_state': '',
#   'venue_id': 2681,
#   'venue_name': 'Citizens Bank Park',
#   'national_broadcasts': ['FOX'],
#   'summary': '2022-08-20 - New York Mets @ Philadelphia Phillies (Scheduled)'},
#  {'game_id': 661240,
#   'game_datetime': '2022-08-20T17:05:00Z',
#   'game_date': '2022-08-20',
#   'game_type': 'R',
#   'status': 'Final',
#   'away_name': 'Toronto Blue Jays',
#   'home_name': 'New York Yankees',
#   'away_id': 141,
#   'home_id': 147,
#   'doubleheader': 'N',
#   'game_num': 1,
#   'home_probable_pitcher': 'Gerrit Cole',
#   'away_probable_pitcher': 'Mitch White',
#   'home_pitcher_note': '',
#   'away_pitcher_note': '',
#   'away_score': 5,
#   'home_score': 2,
#   'current_inning': 9,
#   'inning_state': 'Bottom',
#   'venue_id': 3313,
#   'venue_name': 'Yankee Stadium',
#   'national_broadcasts': ['MLBN (out-of-market only)'],
#   'winning_team': 'Toronto Blue Jays',
#   'losing_team': 'New York Yankees',
#   'winning_pitcher': 'Adam Cimber',
#   'losing_pitcher': 'Gerrit Cole',
#   'save_pitcher': 'Yimi Garcia',
#   'summary': '2022-08-20 - Toronto Blue Jays (5) @ New York Yankees (2) (Final)'},
#  {'game_id': 662917,
#   'game_datetime': '2022-08-20T17:10:00Z',
#   'game_date': '2022-08-20',
#   'game_type': 'R',
#   'status': 'Final',
#   'away_name': 'Los Angeles Angels',
#   'home_name': 'Detroit Tigers',
#   'away_id': 108,
#   'home_id': 116,
#   'doubleheader': 'N',
#   'game_num': 1,
#   'home_probable_pitcher': 'Tyler Alexander',
#   'away_probable_pitcher': 'Reid Detmers',
#   'home_pitcher_note': '',
#   'away_pitcher_note': '',
#   'away_score': 3,
#   'home_score': 4,
#   'current_inning': 9,
#   'inning_state': 'Top',
#   'venue_id': 2394,
#   'venue_name': 'Comerica Park',
#   'national_broadcasts': ['MLBN (out-of-market only)'],
#   'winning_team': 'Detroit Tigers',
#   'losing_team': 'Los Angeles Angels',
#   'winning_pitcher': 'Tyler Alexander',
#   'losing_pitcher': 'Reid Detmers',
#   'save_pitcher': 'Gregory Soto',
#   'summary': '2022-08-20 - Los Angeles Angels (3) @ Detroit Tigers (4) (Final)'},
#  {'game_id': 663116,
#   'game_datetime': '2022-08-20T18:20:00Z',
#   'game_date': '2022-08-20',
#   'game_type': 'R',
#   'status': 'In Progress',
#   'away_name': 'Milwaukee Brewers',
#   'home_name': 'Chicago Cubs',
#   'away_id': 158,
#   'home_id': 112,
#   'doubleheader': 'N',
#   'game_num': 1,
#   'home_probable_pitcher': 'Marcus Stroman',
#   'away_probable_pitcher': 'Freddy Peralta',
#   'home_pitcher_note': '',
#   'away_pitcher_note': '',
#   'away_score': 1,
#   'home_score': 2,
#   'current_inning': 7,
#   'inning_state': 'Top',
#   'venue_id': 17,
#   'venue_name': 'Wrigley Field',
#   'national_broadcasts': ['FS1'],
#   'summary': '2022-08-20 - Milwaukee Brewers (1) @ Chicago Cubs (2) (Top of the 7th)'},
#  {'game_id': 661043,
#   'game_datetime': '2022-08-20T20:05:00Z',
#   'game_date': '2022-08-20',
#   'game_type': 'R',
#   'status': 'In Progress',
#   'away_name': 'Boston Red Sox',
#   'home_name': 'Baltimore Orioles',
#   'away_id': 111,
#   'home_id': 110,
#   'doubleheader': 'N',
#   'game_num': 1,
#   'home_probable_pitcher': 'Kyle Bradish',
#   'away_probable_pitcher': 'Michael Wacha',
#   'home_pitcher_note': '',
#   'away_pitcher_note': '',
#   'away_score': 0,
#   'home_score': 0,
#   'current_inning': 3,
#   'inning_state': 'Top',
#   'venue_id': 2,
#   'venue_name': 'Oriole Park at Camden Yards',
#   'national_broadcasts': [],
#   'summary': '2022-08-20 - Boston Red Sox (0) @ Baltimore Orioles (0) (Top of the 3rd)'},
#  {'game_id': 661861,
#   'game_datetime': '2022-08-20T20:10:00Z',
#   'game_date': '2022-08-20',
#   'game_type': 'R',
#   'status': 'In Progress',
#   'away_name': 'Kansas City Royals',
#   'home_name': 'Tampa Bay Rays',
#   'away_id': 118,
#   'home_id': 139,
#   'doubleheader': 'N',
#   'game_num': 1,
#   'home_probable_pitcher': 'Drew Rasmussen',
#   'away_probable_pitcher': 'Kris Bubic',
#   'home_pitcher_note': '',
#   'away_pitcher_note': '',
#   'away_score': 0,
#   'home_score': 0,
#   'current_inning': 2,
#   'inning_state': 'Bottom',
#   'venue_id': 12,
#   'venue_name': 'Tropicana Field',
#   'national_broadcasts': [],
#   'summary': '2022-08-20 - Kansas City Royals (0) @ Tampa Bay Rays (0) (Bottom of the 2nd)'},
#  {'game_id': 662953,
#   'game_datetime': '2022-08-20T22:10:00Z',
#   'game_date': '2022-08-20',
#   'game_type': 'R',
#   'status': 'Pre-Game',
#   'away_name': 'Chicago White Sox',
#   'home_name': 'Cleveland Guardians',
#   'away_id': 145,
#   'home_id': 114,
#   'doubleheader': 'N',
#   'game_num': 1,
#   'home_probable_pitcher': 'Shane Bieber',
#   'away_probable_pitcher': 'Johnny Cueto',
#   'home_pitcher_note': '',
#   'away_pitcher_note': '',
#   'away_score': 0,
#   'home_score': 0,
#   'current_inning': 1,
#   'inning_state': 'Top',
#   'venue_id': 5,
#   'venue_name': 'Progressive Field',
#   'national_broadcasts': [],
#   'summary': '2022-08-20 - Chicago White Sox @ Cleveland Guardians (Pre-Game)'},
#  {'game_id': 662395,
#   'game_datetime': '2022-08-20T23:05:00Z',
#   'game_date': '2022-08-20',
#   'game_type': 'R',
#   'status': 'Pre-Game',
#   'away_name': 'Cincinnati Reds',
#   'home_name': 'Pittsburgh Pirates',
#   'away_id': 113,
#   'home_id': 134,
#   'doubleheader': 'N',
#   'game_num': 1,
#   'home_probable_pitcher': 'Tyler Beede',
#   'away_probable_pitcher': 'Justin Dunn',
#   'home_pitcher_note': '',
#   'away_pitcher_note': '',
#   'away_score': 0,
#   'home_score': 0,
#   'current_inning': 1,
#   'inning_state': 'Top',
#   'venue_id': 31,
#   'venue_name': 'PNC Park',
#   'national_broadcasts': [],
#   'summary': '2022-08-20 - Cincinnati Reds @ Pittsburgh Pirates (Pre-Game)'},
#  {'game_id': 661670,
#   'game_datetime': '2022-08-20T23:10:00Z',
#   'game_date': '2022-08-20',
#   'game_type': 'R',
#   'status': 'Pre-Game',
#   'away_name': 'Texas Rangers',
#   'home_name': 'Minnesota Twins',
#   'away_id': 140,
#   'home_id': 142,
#   'doubleheader': 'N',
#   'game_num': 1,
#   'home_probable_pitcher': 'Chris Archer',
#   'away_probable_pitcher': 'Glenn Otto',
#   'home_pitcher_note': '',
#   'away_pitcher_note': '',
#   'away_score': 0,
#   'home_score': 0,
#   'current_inning': 1,
#   'inning_state': 'Top',
#   'venue_id': 3312,
#   'venue_name': 'Target Field',
#   'national_broadcasts': [],
#   'summary': '2022-08-20 - Texas Rangers @ Minnesota Twins (Pre-Game)'},
#  {'game_id': 662340,
#   'game_datetime': '2022-08-20T23:15:00Z',
#   'game_date': '2022-08-20',
#   'game_type': 'R',
#   'status': 'Pre-Game',
#   'away_name': 'Seattle Mariners',
#   'home_name': 'Oakland Athletics',
#   'away_id': 136,
#   'home_id': 133,
#   'doubleheader': 'N',
#   'game_num': 1,
#   'home_probable_pitcher': 'James Kaprielian',
#   'away_probable_pitcher': 'Logan Gilbert',
#   'home_pitcher_note': '',
#   'away_pitcher_note': '',
#   'away_score': 0,
#   'home_score': 0,
#   'current_inning': 1,
#   'inning_state': 'Top',
#   'venue_id': 10,
#   'venue_name': 'Oakland Coliseum',
#   'national_broadcasts': ['FOX'],
#   'summary': '2022-08-20 - Seattle Mariners @ Oakland Athletics (Pre-Game)'},
#  {'game_id': 661610,
#   'game_datetime': '2022-08-20T23:15:00Z',
#   'game_date': '2022-08-20',
#   'game_type': 'R',
#   'status': 'Pre-Game',
#   'away_name': 'Houston Astros',
#   'home_name': 'Atlanta Braves',
#   'away_id': 117,
#   'home_id': 144,
#   'doubleheader': 'N',
#   'game_num': 1,
#   'home_probable_pitcher': 'Spencer Strider',
#   'away_probable_pitcher': 'Cristian Javier',
#   'home_pitcher_note': '',
#   'away_pitcher_note': '',
#   'away_score': 0,
#   'home_score': 0,
#   'current_inning': 1,
#   'inning_state': 'Top',
#   'venue_id': 4705,
#   'venue_name': 'Truist Park',
#   'national_broadcasts': ['FOX'],
#   'summary': '2022-08-20 - Houston Astros @ Atlanta Braves (Pre-Game)'},
#  {'game_id': 662879,
#   'game_datetime': '2022-08-21T00:10:00Z',
#   'game_date': '2022-08-20',
#   'game_type': 'R',
#   'status': 'Pre-Game',
#   'away_name': 'San Francisco Giants',
#   'home_name': 'Colorado Rockies',
#   'away_id': 137,
#   'home_id': 115,
#   'doubleheader': 'N',
#   'game_num': 1,
#   'home_probable_pitcher': 'Ryan Feltner',
#   'away_probable_pitcher': 'Alex Cobb',
#   'home_pitcher_note': '',
#   'away_pitcher_note': '',
#   'away_score': 0,
#   'home_score': 0,
#   'current_inning': 1,
#   'inning_state': 'Top',
#   'venue_id': 19,
#   'venue_name': 'Coors Field',
#   'national_broadcasts': [],
#   'summary': '2022-08-20 - San Francisco Giants @ Colorado Rockies (Pre-Game)'},
#  {'game_id': 663291,
#   'game_datetime': '2022-08-21T00:10:00Z',
#   'game_date': '2022-08-20',
#   'game_type': 'R',
#   'status': 'Pre-Game',
#   'away_name': 'St. Louis Cardinals',
#   'home_name': 'Arizona Diamondbacks',
#   'away_id': 138,
#   'home_id': 109,
#   'doubleheader': 'N',
#   'game_num': 1,
#   'home_probable_pitcher': 'Madison Bumgarner',
#   'away_probable_pitcher': 'Dakota Hudson',
#   'home_pitcher_note': '',
#   'away_pitcher_note': '',
#   'away_score': '0',
#   'home_score': '0',
#   'current_inning': '',
#   'inning_state': '',
#   'venue_id': 15,
#   'venue_name': 'Chase Field',
#   'national_broadcasts': [],
#   'summary': '2022-08-20 - St. Louis Cardinals @ Arizona Diamondbacks (Pre-Game)'},
#  {'game_id': 662180,
#   'game_datetime': '2022-08-21T00:40:00Z',
#   'game_date': '2022-08-20',
#   'game_type': 'R',
#   'status': 'Pre-Game',
#   'away_name': 'Washington Nationals',
#   'home_name': 'San Diego Padres',
#   'away_id': 120,
#   'home_id': 135,
#   'doubleheader': 'N',
#   'game_num': 1,
#   'home_probable_pitcher': 'Joe Musgrove',
#   'away_probable_pitcher': 'Josiah Gray',
#   'home_pitcher_note': '',
#   'away_pitcher_note': '',
#   'away_score': '0',
#   'home_score': '0',
#   'current_inning': '',
#   'inning_state': '',
#   'venue_id': 2680,
#   'venue_name': 'Petco Park',
#   'national_broadcasts': [],
#   'summary': '2022-08-20 - Washington Nationals @ San Diego Padres (Pre-Game)'},
#  {'game_id': 662561,
#   'game_datetime': '2022-08-21T01:10:00Z',
#   'game_date': '2022-08-20',
#   'game_type': 'R',
#   'status': 'Scheduled',
#   'away_name': 'Miami Marlins',
#   'home_name': 'Los Angeles Dodgers',
#   'away_id': 146,
#   'home_id': 119,
#   'doubleheader': 'N',
#   'game_num': 1,
#   'home_probable_pitcher': '',
#   'away_probable_pitcher': 'Braxton Garrett',
#   'home_pitcher_note': '',
#   'away_pitcher_note': '',
#   'away_score': '0',
#   'home_score': '0',
#   'current_inning': '',
#   'inning_state': '',
#   'venue_id': 22,
#   'venue_name': 'Dodger Stadium',
#   'national_broadcasts': [],
#   'summary': '2022-08-20 - Miami Marlins @ Los Angeles Dodgers (Scheduled)'}]

# %%
game_DF = pd.DataFrame({"Game":[], "Time" : []})
game_DF
# Out:
# Empty DataFrame
# Columns: [Game, Time]
# Index: []

# %%
stadium_info = [{"team":"Los Angeles Angels","address":"2000 Gene Autry Way, Anaheim, CA. 92806","lat":33.799572,"lng":-117.889031},
                {"team":"Arizona Diamondbacks","address":"P.O. Box 2095, Phoenix, AZ. 85001","lat":33.452922,"lng":-112.038669},
                {"team":"Atlanta Braves","address":"P.O. Box 4064, Atlanta, GA. 30302","lat":33.74691,"lng":-84.391239},
                {"team":"Baltimore Orioles","address":"333 W. Camden Street, Baltimore, MD. 21201","lat":39.285243,"lng":-76.620103},
                {"team":"Boston Red Sox","address":"4 Yawkey Way, Boston, MA 02215","lat":42.346613,"lng":-71.098817},
                {"team":"Chicago Cubs","address":"1060 Addison Street, Chicago, IL 60616","lat":41.947201,"lng":-87.656413},
                {"team":"Chicago White Sox","address":"333 W. 35th Street, Chicago, IL 60616","lat":41.830883,"lng":-87.635083},
                {"team":"Cincinnati Reds","address":"100 Cinergy Field, Cincinnati, OH 45202","lat":39.107183,"lng":-84.507713},
                {"team":"Cleveland Guardians","address":"2401 Ontario Street, Cleveland, OH 44115","lat":41.495149,"lng":-81.68709},
                {"team":"Colorado Rockies","address":"Coors Field, 2001 Blake Street, Denver, CO 80205-2000","lat":39.75698,"lng":-104.965329},
                {"team":"Detroit Tigers","address":"Comerica Park, 2100 Woodward Ave., Detroit, MI 48201","lat":42.346354,"lng":-83.059619},
                {"team":"Florida Marlins","address":"2269 NW 199th Street, Miami, FL 33056","lat":25.954428,"lng":-80.238164},
                {"team":"Houston Astros","address":"P.O. Box 288, Houston, TX 77001-0288","lat":29.76045,"lng":-95.369784},
                {"team":"Kansas City Royals","address":"P.O. Boz 419969, Kansas City, MO 64141","lat":39.10222,"lng":-94.583559},
                {"team":"Los Angeles Dodgers","address":"1000 Elysian Park Ave., Los Angeles, CA 90012","lat":34.072437,"lng":-118.246879},
                {"team":"Milwaukee Brewers","address":"P.O. Box 3099, Milwaukee, WI 53201-3099","lat":43.04205,"lng":-87.905599},
                {"team":"Minnesota Twins","address":"501 Chicago Ave. S., Minneapolis, MN 55415","lat":44.974346,"lng":-93.259616},
                {"team":"New York Mets","address":"Roosevelt Ave & 126th Street, New York, NY 11368","lat":40.75535,"lng":-73.843219},
                {"team":"New York Yankees","address":"Yankee Stadium, E. 161 Street & River Ave., New York, NY 10451","lat":40.819782,"lng":-73.929939},
                {"team":"Oakland Athletics","address":"Oakland Coliseum, 700 Coliseum Way, Oakland, Ca 94621-1918","lat":37.74923,"lng":-122.196487},
                {"team":"Philadelphia Phillies","address":"P.O. Box 7575, Philadelphia, PA 19101","lat":39.952313,"lng":-75.162392},
                {"team":"Pittsburgh Pirates","address":"600 Stadium Circle, Pittsburgh, PA 15212","lat":40.461503,"lng":-80.008924},
                {"team":"St. Louis Cardinals","address":"250 Stadium Plaza, St. Louis, MO 63102","lat":38.629683,"lng":-90.188247},
                {"team":"San Diego Padres","address":"P.O. Box 2000, San Diego, CA 92112-2000","lat":32.752148,"lng":-117.143635},
                {"team":"San Francisco Giants","address":"Pacific Bell Park, 24 Willie Mays Plaza, San Francisco, CA 94107","lat":37.77987,"lng":-122.389754},
                {"team":"Seattle Mariners","address":"P.O. Box 41000, 411 First Ave. S., Seattle, WA 98104","lat":47.60174,"lng":-122.330829},
                {"team":"Tampa Bay Rays","address":"1 Tropicana Drive, St. Petersburg, FL 33705","lat":27.768487,"lng":-82.648191},
                {"team":"Texas Rangers","address":"1000 Ballpark Way, Arlington, TX 76011","lat":32.750156,"lng":-97.081117},
                {"team":"Toronto Blue Jays","address":"1 Blue Jay Way, Suite 3200, Toronto, ONT M5V 1J1","lat":43.641653,"lng":-79.3917},
                {"team":"Washington Nationals","address":"1500 South Capitol Street SE, Washington, DC","lat":38.87,"lng":-77.01}]

# %%
x = list(filter(lambda team: team['team'] == 'Toronto Blue Jays', stadium_info))[0]
x
print(x['lng'])
print(x['lat'])
# Out:
# -79.3917
# 43.641653

# %%
gameList = []
games_list = []
games_times = []
location_list = []
doubleheader_count = 0
for game in sched:
    home_team = game['home_name']
    away_team = game['away_name']
    location_data = list(filter(lambda team: team['team'] == home_team, stadium_info))
    location_list.append([location_data['lng'], location_data['lat']])

    teams = away_team + " @ " + home_team 
    game_time = game['game_datetime']


    if game['doubleheader'] == 'S':
        if doubleheader_count == 0:
            doubleheader_count = 1
            teams = teams + " Game 1"
        else:
            teams = teams + " Game 2"


    game_time = re.findall('\d{2}:\d{2}', game_time)[0]
    
    hour = int(game_time[:2])

    #Time Change for when games start at [1,5] AM 
    if hour <= 5:
        hour = 24 + hour
        
    hour = hour - 7 #MST     
    min = game_time[3:]
    if hour >= 12:
        std_time =  hour % 12
        if std_time == 0:
            std_time = 12
        game_time = str(std_time) + ':' + min + " PM MST"
    else:
        game_time = str(hour) + ':' + min + " AM MST"
    
    games_list.append(teams)
    games_times.append(game_time)
    gameList.append(home_team + " vs " + away_team + " @ " + game_time)


game_DF["Game"] = games_list
game_DF["Time"] = games_times
game_DF["Location"] = location_list
print(game_DF)
print(gameList)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/christopherquintas/Desktop/Programming/Projects/MLB_DataVisualizer/MLB_StatVis_Test.ipynb Cell 8 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/Users/christopherquintas/Desktop/Programming/Projects/MLB_DataVisualizer/MLB_StatVis_Test.ipynb#ch0000003?line=7'>8</a> away_team = game['away_name']
#       <a href='vscode-notebook-cell:/Users/christopherquintas/Desktop/Programming/Projects/MLB_DataVisualizer/MLB_StatVis_Test.ipynb#ch0000003?line=8'>9</a> location_data = list(filter(lambda team: team['team'] == home_team, stadium_info))
# ---> <a href='vscode-notebook-cell:/Users/christopherquintas/Desktop/Programming/Projects/MLB_DataVisualizer/MLB_StatVis_Test.ipynb#ch0000003?line=9'>10</a> location_list.append([location_data['lng'], location_data['lat']])
#      <a href='vscode-notebook-cell:/Users/christopherquintas/Desktop/Programming/Projects/MLB_DataVisualizer/MLB_StatVis_Test.ipynb#ch0000003?line=11'>12</a> teams = away_team + " @ " + home_team
#      <a href='vscode-notebook-cell:/Users/christopherquintas/Desktop/Programming/Projects/MLB_DataVisualizer/MLB_StatVis_Test.ipynb#ch0000003?line=12'>13</a> game_time = game['game_datetime']
#
# TypeError: list indices must be integers or slices, not str

# %%
home_pitcher_list = []
away_pitcher_list = []
for game in sched:
    home_pitcher = game['home_probable_pitcher']
    away_pitcher = game['away_probable_pitcher']
    
    home_pitcher_list.append(home_pitcher)
    away_pitcher_list.append(away_pitcher)


game_DF["Home Pitcher"] = home_pitcher_list
game_DF["Away Pitcher"] = away_pitcher_list
game_DF
# Out:
#                                             Game          Time  \
# 0   New York Mets @ Philadelphia Phillies Game 1  10:05 AM MST
# 1   New York Mets @ Philadelphia Phillies Game 2   4:15 PM MST
# 2           Toronto Blue Jays @ New York Yankees  10:05 AM MST
# 3            Los Angeles Angels @ Detroit Tigers  10:10 AM MST
# 4               Milwaukee Brewers @ Chicago Cubs  11:20 AM MST
# 5             Boston Red Sox @ Baltimore Orioles   1:05 PM MST
# 6            Kansas City Royals @ Tampa Bay Rays   1:10 PM MST
# 7        Chicago White Sox @ Cleveland Guardians   3:10 PM MST
# 8           Cincinnati Reds @ Pittsburgh Pirates   4:05 PM MST
# 9                Texas Rangers @ Minnesota Twins   4:10 PM MST
# 10          Seattle Mariners @ Oakland Athletics   4:15 PM MST
# 11               Houston Astros @ Atlanta Braves   4:15 PM MST
# 12       San Francisco Giants @ Colorado Rockies   5:10 PM MST
# 13    St. Louis Cardinals @ Arizona Diamondbacks   5:10 PM MST
# 14       Washington Nationals @ San Diego Padres   5:40 PM MST
# 15           Miami Marlins @ Los Angeles Dodgers   6:10 PM MST
#
#          Home Pitcher     Away Pitcher
# 0        Zack Wheeler  Trevor Williams
# 1       Bailey Falter   David Peterson
# 2         Gerrit Cole      Mitch White
# 3     Tyler Alexander     Reid Detmers
# 4      Marcus Stroman   Freddy Peralta
# 5        Kyle Bradish    Michael Wacha
# 6      Drew Rasmussen       Kris Bubic
# 7        Shane Bieber     Johnny Cueto
# 8         Tyler Beede      Justin Dunn
# 9        Chris Archer       Glenn Otto
# 10   James Kaprielian    Logan Gilbert
# 11    Spencer Strider  Cristian Javier
# 12       Ryan Feltner        Alex Cobb
# 13  Madison Bumgarner    Dakota Hudson
# 14       Joe Musgrove      Josiah Gray
# 15                     Braxton Garrett

# %%
url = "http://www.7timer.info/bin/api.pl?lon={lon}&lat={lat}&product={product}&output={type}"
